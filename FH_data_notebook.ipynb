# %% [markdown]
# <a href="https://colab.research.google.com/github/zqiaohe/100daysofcode/blob/master/FH_data_notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %% [markdown]
# #Подготовка данных

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('drive/My Drive/FH_data/PregPred.csv')

# %%
data
# Out:
#                                         ФИО  Возраст               1  \
# 0             Фалилеева Наталья Викторовна                        37
# 1           Афанасьева Ксения Владимировна                        29
# 2              Квирикадзе  Наталья Юрьевна                        36
# 3                Захаренко Елена Николаевна                       27
# 4               Карпушкина Елена Викторовна                       30
# 5               Волкова Наталья Валерьевна                        36
# 6           Катаманова Юлия Александровна                         38
# 7            Михайлова Марина Геннадьевна                         30
# 8              Хопрячкова Любовь Николаевна                       30
# 9             Козлова Надежда Александровна                       30
# 10           Голубева Екатерина Михайловна                        28
# 11                 Алексева Елена Сергеевна                       26
# 12                 Мишина Ольга Алексеевна                        36
# ...

# %%
 data['ИСХОД     108'].value_counts().plot.bar()

# %%
first100 = data.loc[:100,:]

# %%
tail = data.loc[100:200,:]

# %%
first100['ИСХОД     108'].value_counts().plot.bar()

# %%
tail['ИСХОД     108'].value_counts().plot.bar()

# %%
newtail = tail[tail['ИСХОД     108'] != 1]

# %%
newtail['ИСХОД     108'].value_counts().plot.bar()

# %%
 frames = [first100, newtail]

# %%
result = pd.concat(frames)

# %%
result['ИСХОД     108'].value_counts().plot.bar()

# %%
 result.dropna()
# Out:
#                                         ФИО  Возраст               1  \
# 0             Фалилеева Наталья Викторовна                        37
# 1           Афанасьева Ксения Владимировна                        29
# 2              Квирикадзе  Наталья Юрьевна                        36
# 3                Захаренко Елена Николаевна                       27
# 4               Карпушкина Елена Викторовна                       30
# 5               Волкова Наталья Валерьевна                        36
# 6           Катаманова Юлия Александровна                         38
# 7            Михайлова Марина Геннадьевна                         30
# 8              Хопрячкова Любовь Николаевна                       30
# 9             Козлова Надежда Александровна                       30
# 10           Голубева Екатерина Михайловна                        28
# 11                 Алексева Елена Сергеевна                       26
# 12                 Мишина Ольга Алексеевна                        36
# ...

# %%
result['ИСХОД     108'].value_counts().plot.bar()

# %% [markdown]
# #Нормализация данных

# %%
Y = result['ИСХОД     108']

# %%
X = result.drop('ИСХОД     108', 1)

# %%
X = result.drop('ФИО', 1)

# %%
from sklearn.preprocessing import normalize

# %%
from sklearn import datasets
from sklearn import metrics
from sklearn.tree import DecisionTreeClassifier

# %%
dataset = datasets.load_iris()
# процесс настройки модели CART по выборке данных
model = DecisionTreeClassifier()
model.fit(X, Y)
print(model)
# предсказание
expected = X
predicted = model.predict(X)
# оценка качества работы предсказательной модели
print(metrics.classification_report(expected, predicted))
print(metrics.confusion_matrix(expected, predicted))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-55-0ee28841c822> in <module>()
#       2 # процесс настройки модели CART по выборке данных
#       3 model = DecisionTreeClassifier()
# ----> 4 model.fit(X, Y)
#       5 print(model)
#       6 # предсказание
#
# /usr/local/lib/python3.6/dist-packages/sklearn/tree/tree.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     799             sample_weight=sample_weight,
#     800             check_input=check_input,
# --> 801             X_idx_sorted=X_idx_sorted)
#     802         return self
#     803
#
# /usr/local/lib/python3.6/dist-packages/sklearn/tree/tree.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     114         random_state = check_random_state(self.random_state)
#     115         if check_input:
# --> 116             X = check_array(X, dtype=DTYPE, accept_sparse="csc")
# ...
