# %%
import json
import os
import jsonschema 
import sys
import pandas as pd

# %%
schema_dir = "/content/drive/MyDrive/Honor/task_folder/schema/"
event_dir = "/content/drive/MyDrive/Honor/task_folder/event/"
schemas = os.listdir(schema_dir)
files = os.listdir(event_dir)

# %%
d = {'ErrorSchema': [], 'ErrorFileName': [], 'ErrorMessage': []}
df = pd.DataFrame(data=d)

# %%
for schemaname in schemas:
  with open(schema_dir+schemaname, 'r') as f:
    schema_file = f.read()
  schema = json.loads(schema_file)
  #print(schemaname)
  for filename in files:
    #print(filename)
    with open(event_dir+filename, 'r') as f:
      json_file = f.read()
    json_obj = json.loads(json_file)
    try:
      json_obj.fromkeys(schema.keys())
    except:
      row = [schemaname, filename, 'Empty file']
      df.loc[len(df)] = row
    
    try:
      jsonschema.validate(json_obj, schema)
    except:
      exc_type, exc_value, exc_traceback = sys.exc_info()
      row = [schemaname, filename, str(exc_value.message)]
      df.loc[len(df)] = row

# %%
df
# Out:
#                ErrorSchema  ...                            ErrorMessage
# 0   cmarker_created.schema  ...       'cmarkers' is a required property
# 1   cmarker_created.schema  ...       'cmarkers' is a required property
# 2   cmarker_created.schema  ...       'cmarkers' is a required property
# 3   cmarker_created.schema  ...       'cmarkers' is a required property
# 4   cmarker_created.schema  ...       'cmarkers' is a required property
# ..                     ...  ...                                     ...
# 63  workout_created.schema  ...  'activity_name' is a required property
# 64  workout_created.schema  ...  'activity_name' is a required property
# 65  workout_created.schema  ...                              Empty file
# 66  workout_created.schema  ...            None is not of type 'object'
# 67  workout_created.schema  ...  'activity_name' is a required property
#
# [68 rows x 3 columns]

# %%
print(df.to_html())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>ErrorSchema</th>
#       <th>ErrorFileName</th>
#       <th>ErrorMessage</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>cmarker_created.schema</td>
#       <td>ba25151c-914f-4f47-909a-7a65a6339f34.json</td>
#       <td>'cmarkers' is a required property</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>cmarker_created.schema</td>
#       <td>1eba2aa1-2acf-460d-91e6-55a8c3e3b7a3.json</td>
#       <td>'cmarkers' is a required property</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>cmarker_created.schema</td>
#       <td>cc07e442-7986-4714-8fc2-ac2256690a90.json</td>
#       <td>'cmarkers' is a required property</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>cmarker_created.schema</td>
#       <td>3ade063d-d1b9-453f-85b4-dda7bfda4711.json</td>
#       <td>'cmarkers' is a required property</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>cmarker_created.schema</td>
#       <td>3b4088ef-7521-4114-ac56-57c68632d431.json</td>
#       <td>'cmarkers' is a required property</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>cmarker_created.schema</td>
#       <td>e2d760c3-7e10-4464-ab22-7fda6b5e2562.json</td>
#       <td>'cmarkers' is a required property</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>cmarker_created.schema</td>
#       <td>fb1a0854-9535-404d-9bdd-9ec0abb6cd6c.json</td>
#       <td>'cmarkers' is a required property</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>cmarker_created.schema</td>
#       <td>ffe6b214-d543-40a8-8da3-deb0dc5bbd8c.json</td>
#       <td>'cmarkers' is a required property</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>cmarker_created.schema</td>
#       <td>f5656ff6-29e1-46b0-8d8a-ff77f9cc0953.json</td>
#       <td>'cmarkers' is a required property</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>cmarker_created.schema</td>
#       <td>297e4dc6-07d1-420d-a5ae-e4aff3aedc19.json</td>
#       <td>'cmarkers' is a required property</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>cmarker_created.schema</td>
#       <td>bb998113-bc02-4cd1-9410-d9ae94f53eb0.json</td>
#       <td>'cmarkers' is a required property</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>cmarker_created.schema</td>
#       <td>2e8ffd3c-dbda-42df-9901-b7a30869511a.json</td>
#       <td>'cmarkers' is a required property</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>cmarker_created.schema</td>
#       <td>6b1984e5-4092-4279-9dce-bdaa831c7932.json</td>
#       <td>'cmarkers' is a required property</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>cmarker_created.schema</td>
#       <td>c72d21cf-1152-4d8e-b649-e198149d5bbb.json</td>
#       <td>'cmarkers' is a required property</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>cmarker_created.schema</td>
#       <td>29f0bfa7-bd51-4d45-93be-f6ead1ae0b96.json</td>
#       <td>Empty file</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>cmarker_created.schema</td>
#       <td>29f0bfa7-bd51-4d45-93be-f6ead1ae0b96.json</td>
#       <td>None is not of type 'object'</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>cmarker_created.schema</td>
#       <td>a95d845c-8d9e-4e07-8948-275167643a40.json</td>
#       <td>'cmarkers' is a required property</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>label_selected.schema</td>
#       <td>ba25151c-914f-4f47-909a-7a65a6339f34.json</td>
#       <td>'id' is a required property</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>label_selected.schema</td>
#       <td>1eba2aa1-2acf-460d-91e6-55a8c3e3b7a3.json</td>
#       <td>'id' is a required property</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>label_selected.schema</td>
#       <td>cc07e442-7986-4714-8fc2-ac2256690a90.json</td>
#       <td>'id' is a required property</td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td>label_selected.schema</td>
#       <td>3ade063d-d1b9-453f-85b4-dda7bfda4711.json</td>
#       <td>'labels' is a required property</td>
#     </tr>
#     <tr>
#       <th>21</th>
#       <td>label_selected.schema</td>
#       <td>3b4088ef-7521-4114-ac56-57c68632d431.json</td>
#       <td>'labels' is a required property</td>
#     </tr>
#     <tr>
#       <th>22</th>
#       <td>label_selected.schema</td>
#       <td>e2d760c3-7e10-4464-ab22-7fda6b5e2562.json</td>
#       <td>'labels' is a required property</td>
#     </tr>
#     <tr>
#       <th>23</th>
#       <td>label_selected.schema</td>
#       <td>fb1a0854-9535-404d-9bdd-9ec0abb6cd6c.json</td>
#       <td>'labels' is a required property</td>
#     </tr>
#     <tr>
#       <th>24</th>
#       <td>label_selected.schema</td>
#       <td>ffe6b214-d543-40a8-8da3-deb0dc5bbd8c.json</td>
#       <td>'labels' is a required property</td>
#     </tr>
#     <tr>
#       <th>25</th>
#       <td>label_selected.schema</td>
#       <td>f5656ff6-29e1-46b0-8d8a-ff77f9cc0953.json</td>
#       <td>'labels' is a required property</td>
#     </tr>
#     <tr>
#       <th>26</th>
#       <td>label_selected.schema</td>
#       <td>297e4dc6-07d1-420d-a5ae-e4aff3aedc19.json</td>
#       <td>'labels' is a required property</td>
#     </tr>
#     <tr>
#       <th>27</th>
#       <td>label_selected.schema</td>
#       <td>bb998113-bc02-4cd1-9410-d9ae94f53eb0.json</td>
#       <td>'labels' is a required property</td>
#     </tr>
#     <tr>
#       <th>28</th>
#       <td>label_selected.schema</td>
#       <td>2e8ffd3c-dbda-42df-9901-b7a30869511a.json</td>
#       <td>'labels' is a required property</td>
#     </tr>
#     <tr>
#       <th>29</th>
#       <td>label_selected.schema</td>
#       <td>6b1984e5-4092-4279-9dce-bdaa831c7932.json</td>
#       <td>'labels' is a required property</td>
#     </tr>
#     <tr>
#       <th>30</th>
#       <td>label_selected.schema</td>
#       <td>c72d21cf-1152-4d8e-b649-e198149d5bbb.json</td>
#       <td>'labels' is a required property</td>
#     </tr>
#     <tr>
#       <th>31</th>
#       <td>label_selected.schema</td>
#       <td>29f0bfa7-bd51-4d45-93be-f6ead1ae0b96.json</td>
#       <td>Empty file</td>
#     </tr>
#     <tr>
#       <th>32</th>
#       <td>label_selected.schema</td>
#       <td>29f0bfa7-bd51-4d45-93be-f6ead1ae0b96.json</td>
#       <td>None is not of type 'object'</td>
#     </tr>
#     <tr>
#       <th>33</th>
#       <td>label_selected.schema</td>
#       <td>a95d845c-8d9e-4e07-8948-275167643a40.json</td>
#       <td>'id' is a required property</td>
#     </tr>
#     <tr>
#       <th>34</th>
#       <td>sleep_created.schema</td>
#       <td>ba25151c-914f-4f47-909a-7a65a6339f34.json</td>
#       <td>'source' is a required property</td>
#     </tr>
#     <tr>
#       <th>35</th>
#       <td>sleep_created.schema</td>
#       <td>1eba2aa1-2acf-460d-91e6-55a8c3e3b7a3.json</td>
#       <td>'source' is a required property</td>
#     </tr>
#     <tr>
#       <th>36</th>
#       <td>sleep_created.schema</td>
#       <td>cc07e442-7986-4714-8fc2-ac2256690a90.json</td>
#       <td>'source' is a required property</td>
#     </tr>
#     <tr>
#       <th>37</th>
#       <td>sleep_created.schema</td>
#       <td>3ade063d-d1b9-453f-85b4-dda7bfda4711.json</td>
#       <td>'source' is a required property</td>
#     </tr>
#     <tr>
#       <th>38</th>
#       <td>sleep_created.schema</td>
#       <td>3b4088ef-7521-4114-ac56-57c68632d431.json</td>
#       <td>'source' is a required property</td>
#     </tr>
#     <tr>
#       <th>39</th>
#       <td>sleep_created.schema</td>
#       <td>e2d760c3-7e10-4464-ab22-7fda6b5e2562.json</td>
#       <td>'source' is a required property</td>
#     </tr>
#     <tr>
#       <th>40</th>
#       <td>sleep_created.schema</td>
#       <td>fb1a0854-9535-404d-9bdd-9ec0abb6cd6c.json</td>
#       <td>'source' is a required property</td>
#     </tr>
#     <tr>
#       <th>41</th>
#       <td>sleep_created.schema</td>
#       <td>ffe6b214-d543-40a8-8da3-deb0dc5bbd8c.json</td>
#       <td>'source' is a required property</td>
#     </tr>
#     <tr>
#       <th>42</th>
#       <td>sleep_created.schema</td>
#       <td>f5656ff6-29e1-46b0-8d8a-ff77f9cc0953.json</td>
#       <td>'source' is a required property</td>
#     </tr>
#     <tr>
#       <th>43</th>
#       <td>sleep_created.schema</td>
#       <td>297e4dc6-07d1-420d-a5ae-e4aff3aedc19.json</td>
#       <td>'source' is a required property</td>
#     </tr>
#     <tr>
#       <th>44</th>
#       <td>sleep_created.schema</td>
#       <td>bb998113-bc02-4cd1-9410-d9ae94f53eb0.json</td>
#       <td>'source' is a required property</td>
#     </tr>
#     <tr>
#       <th>45</th>
#       <td>sleep_created.schema</td>
#       <td>2e8ffd3c-dbda-42df-9901-b7a30869511a.json</td>
#       <td>'source' is a required property</td>
#     </tr>
#     <tr>
#       <th>46</th>
#       <td>sleep_created.schema</td>
#       <td>6b1984e5-4092-4279-9dce-bdaa831c7932.json</td>
#       <td>'source' is a required property</td>
#     </tr>
#     <tr>
#       <th>47</th>
#       <td>sleep_created.schema</td>
#       <td>c72d21cf-1152-4d8e-b649-e198149d5bbb.json</td>
#       <td>'source' is a required property</td>
#     </tr>
#     <tr>
#       <th>48</th>
#       <td>sleep_created.schema</td>
#       <td>29f0bfa7-bd51-4d45-93be-f6ead1ae0b96.json</td>
#       <td>Empty file</td>
#     </tr>
#     <tr>
#       <th>49</th>
#       <td>sleep_created.schema</td>
#       <td>29f0bfa7-bd51-4d45-93be-f6ead1ae0b96.json</td>
#       <td>None is not of type 'object'</td>
#     </tr>
#     <tr>
#       <th>50</th>
#       <td>sleep_created.schema</td>
#       <td>a95d845c-8d9e-4e07-8948-275167643a40.json</td>
#       <td>'source' is a required property</td>
#     </tr>
#     <tr>
#       <th>51</th>
#       <td>workout_created.schema</td>
#       <td>ba25151c-914f-4f47-909a-7a65a6339f34.json</td>
#       <td>'activity_name' is a required property</td>
#     </tr>
#     <tr>
#       <th>52</th>
#       <td>workout_created.schema</td>
#       <td>1eba2aa1-2acf-460d-91e6-55a8c3e3b7a3.json</td>
#       <td>'activity_name' is a required property</td>
#     </tr>
#     <tr>
#       <th>53</th>
#       <td>workout_created.schema</td>
#       <td>cc07e442-7986-4714-8fc2-ac2256690a90.json</td>
#       <td>'activity_name' is a required property</td>
#     </tr>
#     <tr>
#       <th>54</th>
#       <td>workout_created.schema</td>
#       <td>3ade063d-d1b9-453f-85b4-dda7bfda4711.json</td>
#       <td>'activity_name' is a required property</td>
#     </tr>
#     <tr>
#       <th>55</th>
#       <td>workout_created.schema</td>
#       <td>3b4088ef-7521-4114-ac56-57c68632d431.json</td>
#       <td>'activity_name' is a required property</td>
#     </tr>
#     <tr>
#       <th>56</th>
#       <td>workout_created.schema</td>
#       <td>e2d760c3-7e10-4464-ab22-7fda6b5e2562.json</td>
#       <td>'activity_name' is a required property</td>
#     </tr>
#     <tr>
#       <th>57</th>
#       <td>workout_created.schema</td>
#       <td>fb1a0854-9535-404d-9bdd-9ec0abb6cd6c.json</td>
#       <td>'activity_name' is a required property</td>
#     </tr>
#     <tr>
#       <th>58</th>
#       <td>workout_created.schema</td>
#       <td>ffe6b214-d543-40a8-8da3-deb0dc5bbd8c.json</td>
#       <td>'activity_name' is a required property</td>
#     </tr>
#     <tr>
#       <th>59</th>
#       <td>workout_created.schema</td>
#       <td>f5656ff6-29e1-46b0-8d8a-ff77f9cc0953.json</td>
#       <td>'activity_name' is a required property</td>
#     </tr>
#     <tr>
#       <th>60</th>
#       <td>workout_created.schema</td>
#       <td>297e4dc6-07d1-420d-a5ae-e4aff3aedc19.json</td>
#       <td>'activity_name' is a required property</td>
#     </tr>
#     <tr>
#       <th>61</th>
#       <td>workout_created.schema</td>
#       <td>bb998113-bc02-4cd1-9410-d9ae94f53eb0.json</td>
#       <td>'activity_name' is a required property</td>
#     </tr>
#     <tr>
#       <th>62</th>
#       <td>workout_created.schema</td>
#       <td>2e8ffd3c-dbda-42df-9901-b7a30869511a.json</td>
#       <td>'activity_name' is a required property</td>
#     </tr>
#     <tr>
#       <th>63</th>
#       <td>workout_created.schema</td>
#       <td>6b1984e5-4092-4279-9dce-bdaa831c7932.json</td>
#       <td>'activity_name' is a required property</td>
#     </tr>
#     <tr>
#       <th>64</th>
#       <td>workout_created.schema</td>
#       <td>c72d21cf-1152-4d8e-b649-e198149d5bbb.json</td>
#       <td>'activity_name' is a required property</td>
#     </tr>
#     <tr>
#       <th>65</th>
#       <td>workout_created.schema</td>
#       <td>29f0bfa7-bd51-4d45-93be-f6ead1ae0b96.json</td>
#       <td>Empty file</td>
#     </tr>
#     <tr>
#       <th>66</th>
#       <td>workout_created.schema</td>
#       <td>29f0bfa7-bd51-4d45-93be-f6ead1ae0b96.json</td>
#       <td>None is not of type 'object'</td>
#     </tr>
#     <tr>
#       <th>67</th>
#       <td>workout_created.schema</td>
#       <td>a95d845c-8d9e-4e07-8948-275167643a40.json</td>
#       <td>'activity_name' is a required property</td>
#     </tr>
#   </tbody>
# </table>
